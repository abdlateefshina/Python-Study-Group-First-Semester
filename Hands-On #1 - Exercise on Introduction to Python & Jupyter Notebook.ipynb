# %% [markdown]
# # Exercise 1

# %%
print("Hello, World!")
print("My name is AbdLateef.")
print("I am learning Python.")
print("Programming is eciting!")
# Out:
# Hello, World!
# My name is AbdLateef.
# I am learning Python.
# Programming is eciting!

# %% [markdown]
# # Exercise 2

# %%
print("My favourite food is Jollof Rice.")
print("My favourite movie is Avengers: Infinity War.")
print("My favourite sport is Football.")
print("My favourite colour is Blue.")
# Out:
# My favourite food is Jollof Rice.
# My favourite movie is Avengers: Infinity War.
# My favourite sport is Football.
# My favourite colour is Blue.

# %% [markdown]
# # Exercise 3

# %%
print(15+5)
print(30-12)
print(9*8)
print(72/9)
print(18%5)
print(10//3)
print(5**2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 25

# %% [markdown]
# # Exercise 4

# %%
# Display Programming Language
print("Python")
# Display Giving Instructions to a Computer
print("Programming")
# Display The First Module of the Study Group
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One

# %% [markdown]
# # Exercise 5

# %%
# Get to know me
print("My name is AbdLateef Shina")
# Get to know my dream career
print("My dream is becoming a Medical Doctor")
# Where in the whole world you can find me
print("My country is Nigeria")
# Simple Addition
print(25+75)
# Whole Division
print(40//6)
# Exponential Multiplication
print(8**2)
# Out:
# My name is AbdLateef Shina
# My dream is becoming a Medical Doctor
# My country is Nigeria
# 100
# 6
# 64

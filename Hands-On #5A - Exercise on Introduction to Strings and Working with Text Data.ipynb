# %% [markdown]
# # Exercise 1
# ## Customer Registration System

# %%
# Creating the variables.
customer_name = "AbdLateef Shina"
customer_email_address = "abdlateefshina06@gmail.com"
customer_phone_number = "08109724389"
customer_country = "Nigeria"
customer_occupation = "Graphic Designer"

# Printing the customer profile.
print ("Name:", customer_name)
print ("Email Address:", customer_email_address)
print ("Phone Number:", customer_phone_number)
print ("Country:", customer_country)
print ("Occupation:", customer_occupation)
# Out:
# Name: AbdLateef Shina
# Email Address: abdlateefshina06@gmail.com
# Phone Number: 08109724389
# Country: Nigeria
# Occupation: Graphic Designer

# %% [markdown]
# # Exercise 2
# ## Hospital Patient Record

# %%
# Creating the variables.
patient_name = "Okunlola Best"
patient_doctor = "Dr. AbdLateef Shina"
patient_diagnosis = "Malaria"
patient_blood_group = "O+"
patient_hospital = "LAUTECH Teaching Hospital"

# Printing the patient record.
print ("Patient:", patient_name)
print ("Doctor:", patient_doctor)
print ("Diagnosis:", patient_diagnosis)
print ("Blood Group:", patient_blood_group)
print ("Hospital:", patient_hospital)
# Out:
# Patient: Okunlola Best
# Doctor: Dr. AbdLateef Shina
# Diagnosis: Malaria
# Blood Group: O+
# Hospital: LAUTECH Teaching Hospital

# %% [markdown]
# ### Bonus Challenge

# %%
# Printing the patient record using multiline string.
record = '''Patient: {}
Doctor: {}
Diagnosis: {}
Blood Group: {}
Hospital: {}
'''.format(patient_name, patient_doctor, patient_diagnosis, patient_blood_group, patient_hospital)

print (record)
# Out:
# Patient: Okunlola Best
# Doctor: Dr. AbdLateef Shina
# Diagnosis: Malaria
# Blood Group: O+
# Hospital: LAUTECH Teaching Hospital

# %% [markdown]
# # Exercise 3
# ## AI Prompt Builder

# %%
# Printing the prompt using multiline string.
prompt = """You are an AI Assistant.
Analyze customer feedback
Identify common complaints.
Provide recommendations.
Generate a summary report."""

print (prompt)
# Out:
# You are an AI Assistant.
# Analyze customer feedback
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.

# %% [markdown]
# ### Bonus Challenge

# %%
# Adding my own instruction.
prompt = """You are an AI Assistant.
Analyze customer feedback
Identify common complaints.
Provide recommendations.
Generate a summary report.
Visualize the report.
Ask for anything else you can do."""

print (prompt)
# Out:
# You are an AI Assistant.
# Analyze customer feedback
# Identify common complaints.
# Provide recommendations.
# Generate a summary report.
# Visualize the report.
# Ask for anything else you can do.

# %% [markdown]
# # Real-World Case Study Project.
# ## Customer Feedback Management System.

# %%
# Assigning the variables.
customer_name = "Shina AbdLateef"
product_name = "Wireless Mouse"
product_category = "Computer Accessories"
customer_rating = "5 stars"
customer_review = """The product arrived on time, was easy to
install, and exceeded my expectations.
I would definitely recommend it to others."""

# Printing the report.
feedback_report = """
===================================================
            CUSTOMER FEEDBACK REPORT
===================================================

Customer Name: {}
Product: {}
Category: {}
Rating: {}

Customer Review
___________________________________________________
{}
===================================================
Thank you for your feedback!
===================================================
""".format(customer_name, product_name, product_category, customer_rating, customer_review)

print (feedback_report)
# Out:
# ...
#             CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Shina AbdLateef
# Product: Wireless Mouse
# Category: Computer Accessories
# Rating: 5 stars
#
# Customer Review
# ___________________________________________________
# The product arrived on time, was easy to
# install, and exceeded my expectations.
# I would definitely recommend it to others.
# ...
# Thank you for your feedback!
# ...

# %% [markdown]
# ### Bonus Challenge

# %%
# Printing the report again.
feedback_report = """
===================================================
            CUSTOMER FEEDBACK REPORT
===================================================

Customer Name: {}
Product: {}
Category: {}
Rating: {}

Customer Review
___________________________________________________
'{}'
===================================================
Thank you for your feedback!
===================================================
Insight Retail Technologies.
insightretailtech@gmail.com
""".format(customer_name, product_name, product_category, customer_rating, customer_review)

print (feedback_report)
# Out:
# ...
#             CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name: Shina AbdLateef
# Product: Wireless Mouse
# Category: Computer Accessories
# Rating: 5 stars
#
# Customer Review
# ___________________________________________________
# 'The product arrived on time, was easy to
# install, and exceeded my expectations.
# I would definitely recommend it to others.'
# ...
# Thank you for your feedback!
# ...
# Insight Retail Technologies.
# insightretailtech@gmail.com

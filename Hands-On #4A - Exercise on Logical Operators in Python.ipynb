# %% [markdown]
# # Hands-On 1
# ## Secure Login System

# %%
# Conditions for accessibility
username_correct = True
password_correct = True
account_locked = False

# Employee 1 Details
employee1_username_correct = True
employee1_password_correct = True
employee1_account_locked = False

# Checking access
if employee1_username_correct == username_correct and employee1_password_correct == password_correct and employee1_account_locked == account_locked:
    print ("Employee 1:")
    print ("Access Granted")
else:
    print ("Employee 1:")
    print ("Access Denied")
# Out:
# Employee 1:
# Access Granted

# %% [markdown]
# ### Testing for Employee 2

# %%
# Employee 2 Details
employee2_username_correct = False
employee2_password_correct = False
employee2_account_locked = True

# Checking access
if employee2_username_correct == username_correct and employee2_password_correct == password_correct and employee2_account_locked == account_locked:
    print ("Employee 2:")
    print ("Access Granted")
else:
    print ("Employee 2:")
    print ("Access Denied")
# Out:
# Employee 2:
# Access Denied

# %% [markdown]
# # Hands-on 2
# ## University Scholarship Eligibility

# %%
# Conditions for Eligibility
minimum_score = 80
participated = True
low_income = True

# Student 1 Details
student1_score = 85
student1_is_participated = True
student1_is_low_income = False

# Checking Eligibility
if student1_score >= minimum_score and (student1_is_participated == participated or student1_is_low_income == low_income):
    print ("Student 1:")
    print ("Congratulations!")
    print ("Scholarship Approved.")
else:
    print ("Student 1:")
    print ("Scholarship Not Approved")
# Out:
# Student 1:
# Congratulations!
# Scholarship Approved.

# %% [markdown]
# ### Testing for Student 2

# %%
# Student 2 Details
student2_score = 85
student2_is_participated = False
student2_is_low_income = False

# Checking Eligibility
if student2_score >= minimum_score and (student2_is_participated == participated or student2_is_low_income == low_income):
    print ("Student 2:")
    print ("Congratulations!")
    print ("Scholarship Approved.")
else:
    print ("Student 2:")
    print ("Scholarship Not Approved")
# Out:
# Student 2:
# Scholarship Not Approved

# %% [markdown]
# #### "Scholarship Not Approved" because the student neither participate in extracurricular activities nor belong to a low income family.

# %% [markdown]
# ### Testing for Student 3

# %%
# Student 2 Details
student3_score = 60
student3_is_participated = True
student3_is_low_income = False

# Checking Eligibility
if student3_score >= minimum_score and (student3_is_participated == participated or student3_is_low_income == low_income):
    print ("Student 3:")
    print ("Congratulations!")
    print ("Scholarship Approved.")
else:
    print ("Student 3:")
    print ("Scholarship Not Approved")
# Out:
# Student 3:
# Scholarship Not Approved

# %% [markdown]
# #### "Scholarship Not Approved" because the student didn't meet the cutoff mark.

# %% [markdown]
# ### Testing for Student 4

# %%
# Student 2 Details
student4_score = 90
student4_is_participated = True
student4_is_low_income = True

# Checking Eligibility
if student4_score >= minimum_score and (student4_is_participated == participated or student4_is_low_income == low_income):
    print ("Student 4:")
    print ("Congratulations!")
    print ("Scholarship Approved.")
else:
    print ("Student 4:")
    print ("Scholarship Not Approved")
# Out:
# Student 4:
# Congratulations!
# Scholarship Approved.

# %% [markdown]
# #### "Scholarship Approved" because the student met all conditions

# %% [markdown]
# # Hands-on 3
# ## Smart Server Health Monitor

# %%
# Conditions for healthy usage
maximum_cpu_usage = 90
maximum_memory_usage = 90
maximum_disk_usage = 95

# Current details
cpu_usage1 = 75
memory_usage1 = 92
disk_usage1 = 60

# Checking status
if cpu_usage1 > maximum_cpu_usage or memory_usage1 > maximum_memory_usage or disk_usage1 > maximum_disk_usage:
    print ("Critical Alert!")
else:
    print ("System Healthy.")
# Out:
# Critical Alert!

# %% [markdown]
# ### Testing for Situation 2

# %%
# Current details
cpu_usage2 = 75
memory_usage2 = 80
disk_usage2 = 60

# Checking status
if cpu_usage2 > maximum_cpu_usage or memory_usage2 > maximum_memory_usage or disk_usage2 > maximum_disk_usage:
    print ("Critical Alert!")
else:
    print ("System Healthy.")
# Out:
# System Healthy.

# %% [markdown]
# ### Testing for Situation 3

# %%
# Current details
cpu_usage3 = 91
memory_usage3 = 81
disk_usage3 = 60

# Checking status
if cpu_usage3 > maximum_cpu_usage or memory_usage3 > maximum_memory_usage or disk_usage3 > maximum_disk_usage:
    print ("Critical Alert!")
else:
    print ("System Healthy.")
# Out:
# Critical Alert!

# %% [markdown]
# ### Testing for Situation 4

# %%
# Current details
cpu_usage4 = 95
memory_usage4 = 92
disk_usage4 = 98

# Checking status
if cpu_usage4 > maximum_cpu_usage or memory_usage4 > maximum_memory_usage or disk_usage4 > maximum_disk_usage:
    print ("Critical Alert!")
else:
    print ("System Healthy.")
# Out:
# Critical Alert!

# %% [markdown]
# #### Situation 3 alert will trigger first because the CPU just exceed the threshold by just 1 unit.

# %% [markdown]
# # Bonus Challenge

# %%
# Conditions for Order Placement
is_logged_in = True
item_in_stock = True
has_payment_method = True
has_enough_balance = True
account_suspended = False

# Checking for Customer
customer_is_logged_in = True
customer_item_in_stock = True
customer_has_payment_method = True
customer_has_enough_balance = True
customer_account_suspended = False

# Writing the logical Exppression
if customer_is_logged_in == is_logged_in and customer_item_in_stock == item_in_stock and (customer_has_payment_method == has_payment_method or customer_has_enough_balance == has_enough_balance) and customer_account_suspended == account_suspended:
    print ("Order Confirmed")
else:
    print ("Order Failed")
# Out:
# Order Confirmed

# %% [markdown]
# ## Testing Scenario 1

# %%
# Checking for Customer 1
customer1_is_logged_in = True
customer1_item_in_stock = True
customer1_has_payment_method = False
customer1_has_enough_balance = True
customer1_account_suspended = False

# Writing the logical Exppression
if customer1_is_logged_in == is_logged_in and customer1_item_in_stock == item_in_stock and (customer1_has_payment_method == has_payment_method or customer1_has_enough_balance == has_enough_balance) and customer1_account_suspended == account_suspended:
    print ("Order Confirmed")
else:
    print ("Order Failed")
# Out:
# Order Confirmed

# %% [markdown]
# #### Order was confirmed for Scenario 1 because the customer had enough wallet balance for payment instead of a saved payment method.

# %% [markdown]
# ## Testing Scenario 2

# %%
# Checking for Customer 2
customer2_is_logged_in = True
customer2_item_in_stock = True
customer2_has_payment_method = False
customer2_has_enough_balance = False
customer2_account_suspended = False

# Writing the logical Exppression
if customer2_is_logged_in == is_logged_in and customer2_item_in_stock == item_in_stock and (customer2_has_payment_method == has_payment_method or customer2_has_enough_balance == has_enough_balance) and customer2_account_suspended == account_suspended:
    print ("Order Confirmed")
else:
    print ("Order Failed")
# Out:
# Order Failed

# %% [markdown]
# #### Order failed for Scenario 2 because the customer neither have a saved payment method nor enough wallet balance (How would he pay?)

# %% [markdown]
# ## Testing Scenario 3

# %%
# Checking for Customer 3
customer3_is_logged_in = True
customer3_item_in_stock = True
customer3_has_payment_method = True
customer3_has_enough_balance = True
customer3_account_suspended = True

# Writing the logical Exppression
if customer3_is_logged_in == is_logged_in and customer3_item_in_stock == item_in_stock and (customer3_has_payment_method == has_payment_method or customer3_has_enough_balance == has_enough_balance) and customer3_account_suspended == account_suspended:
    print ("Order Confirmed")
else:
    print ("Order Failed")
# Out:
# Order Failed

# %% [markdown]
# #### Order failed for Scenario 3 because despite having different payment options, his account has been suspended.

# %% [markdown]
# ## Testing Scenario 4

# %%
# Checking for Customer 4
customer4_is_logged_in = False
customer4_item_in_stock = True
customer4_has_payment_method = True
customer4_has_enough_balance = True
customer4_account_suspended = False

# Writing the logical Exppression
if customer4_is_logged_in == is_logged_in and customer4_item_in_stock == item_in_stock and (customer4_has_payment_method == has_payment_method or customer4_has_enough_balance == has_enough_balance) and customer4_account_suspended == account_suspended:
    print ("Order Confirmed")
else:
    print ("Order Failed")
# Out:
# Order Failed

# %% [markdown]
# #### Order failed for Scenario 4 because the customer isn't logged in.

# %% [markdown]
# ## Testing Scenario 5

# %%
# Checking for Customer 5
customer5_is_logged_in = False
customer5_item_in_stock = False
customer5_has_payment_method = False
customer5_has_enough_balance = False
customer5_account_suspended = True

# Writing the logical Exppression
if customer5_is_logged_in == is_logged_in and customer5_item_in_stock == item_in_stock and (customer5_has_payment_method == has_payment_method or customer5_has_enough_balance == has_enough_balance) and customer5_account_suspended == account_suspended:
    print ("Order Confirmed")
else:
    print ("Order Failed")
# Out:
# Order Failed

# %% [markdown]
# #### Order failed for Scenario 5 because none of the conditions were met.
